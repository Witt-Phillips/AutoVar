# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from src import *

# %%
# Sample the Binomial provided by random
nsamples = 10000

prog = Dist(Binomial(10, 0.5), nsamples)
print(prog)
print("Mean: ", prog.estimate(), "Variance: ", prog.variance().estimate())

prog2 = Dist(BinomialNative(10, 0.5), nsamples)
print(pretty(prog2))
print("Mean: ", prog2.estimate(), "Variance: ", prog2.variance().estimate())
# Out:
# Dist(Sampler(Binomial(10, 0.5)), 10000)
# Mean:  5.0019 Variance:  2.4963
# Dist(n=10000)
# └─ Add
#    ├─ Add
#    │  ├─ Add
#    │  │  ├─ Add
#    │  │  │  ├─ Add
#    │  │  │  │  ├─ Add
#    │  │  │  │  │  ├─ Add
#    │  │  │  │  │  │  ├─ Add
#    │  │  │  │  │  │  │  ├─ Add
#    │  │  │  │  │  │  │  │  ├─ Sampler(BernoulliNative(0.5))
#    │  │  │  │  │  │  │  │  └─ Sampler(BernoulliNative(0.5))
#    │  │  │  │  │  │  │  └─ Sampler(BernoulliNative(0.5))
#    │  │  │  │  │  │  └─ Sampler(BernoulliNative(0.5))
#    │  │  │  │  │  └─ Sampler(BernoulliNative(0.5))
#    │  │  │  │  └─ Sampler(BernoulliNative(0.5))
#    │  │  │  └─ Sampler(BernoulliNative(0.5))
#    │  │  └─ Sampler(BernoulliNative(0.5))
#    │  └─ Sampler(BernoulliNative(0.5))
#    └─ Sampler(BernoulliNative(0.5))
# Mean:  4.9986 Variance:  2.48965
