# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from src import *

# %%
# Sample the Binomial provided by random
nsamples = 10000

prog = Dist(Binomial(10, 0.5), nsamples)
print("Mean: ", prog.estimate(), "Variance: ", prog.variance().estimate())

prog2 = Dist(BinomialNative(10, 0.5), nsamples)
print(prog2)
print("Mean: ", prog2.estimate(), "Variance: ", prog2.variance().estimate())
# Out:
# Mean:  5.0077 Variance:  2.4549
# Dist(Add(Add(Add(Add(Add(Add(Add(Add(Add(Sampler(<function BernoulliNative.<locals>.<lambda> at 0x106086660>), Sampler(<function BernoulliNative.<locals>.<lambda> at 0x1060865c0>)), Sampler(<function BernoulliNative.<locals>.<lambda> at 0x106086700>)), Sampler(<function BernoulliNative.<locals>.<lambda> at 0x1060867a0>)), Sampler(<function BernoulliNative.<locals>.<lambda> at 0x106086840>)), Sampler(<function BernoulliNative.<locals>.<lambda> at 0x1060868e0>)), Sampler(<function BernoulliNative.<locals>.<lambda> at 0x106086980>)), Sampler(<function BernoulliNative.<locals>.<lambda> at 0x106086a20>)), Sampler(<function BernoulliNative.<locals>.<lambda> at 0x106086ac0>)), Sampler(<function BernoulliNative.<locals>.<lambda> at 0x106086b60>)), 10000)
# Mean:  5.0146 Variance:  2.497
